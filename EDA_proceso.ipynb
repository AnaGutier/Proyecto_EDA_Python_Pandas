# %% [markdown]
# # Proyecto EDA con Python
#
# Para realizar este proyecto cargo todas las librerías necesarias como son NumPy o Pandas

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# Seguidamente, importo los arcivos recibidos (de formato csv y xlsx) para poder observar los datos con los que voy a trabajar, para saber de qué tratan, cómo estan organizados, etc.

# %%
df_bank = pd.read_csv('datos_proyecto/bank-additional.csv', #Señalo la ruta del archivo
                      sep = ',', #Identifico el separador
                      header = 0, # Fila de encabezado
                      index_col = None) #No habrá índice del Dataframe
 
df_bank
# Out:
#        Unnamed: 0   age          job  marital            education  default  \
# 0               0   NaN    housemaid  MARRIED             basic.4y      0.0
# 1               1  57.0     services  MARRIED          high.school      NaN
# 2               2  37.0     services  MARRIED          high.school      0.0
# 3               3  40.0       admin.  MARRIED             basic.6y      0.0
# 4               4  56.0     services  MARRIED          high.school      0.0
# ...           ...   ...          ...      ...                  ...      ...
# 42995       19154   NaN       admin.  MARRIED    university.degree      0.0
# 42996       26206  34.0   technician  MARRIED  professional.course      0.0
# 42997       15046   NaN  blue-collar   SINGLE             basic.6y      0.0
# 42998       15280   NaN       admin.  MARRIED    university.degree      NaN
# 42999       27570   NaN   unemployed   SINGLE    university.degree      0.0
#
# ...

# %%
df_customer = pd.read_excel ('datos_proyecto/customer-details.xlsx',
                      sheet_name = 0,
                      header = 0,
                      index_col = None)

df_customer
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  161770        1         0  2012-04-04                 29
# 1               1   85477        1         1  2012-12-30                  7
# 2               2  147233        1         1  2012-02-02                  5
# 3               3  121393        1         2  2012-12-21                 29
# 4               4   63164        1         2  2012-06-20                 20
# ...           ...     ...      ...       ...         ...                ...
# 20110       20110  114469        0         2  2012-10-28                 13
# 20111       20111   82207        0         1  2012-02-10                 27
# 20112       20112  135009        0         0  2012-09-14                 17
# 20113       20113    8486        1         1  2012-07-04                 18
# 20114       20114  144419        1         0  2012-04-12                 29
#
#                                          ID
# ...

# %%
df_customer = pd.read_excel ('datos_proyecto/customer-details.xlsx',
                      sheet_name = 1,
                      header = 0,
                      index_col = None)

df_customer
# Out:
#       Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0              0   82407        0         1  2013-10-07                 29
# 1              1   24877        0         0  2013-04-21                 32
# 2              2   78839        1         0  2013-11-25                 21
# 3              3  113859        1         1  2013-01-06                 12
# 4              4  147317        0         0  2013-07-10                 14
# ...          ...     ...      ...       ...         ...                ...
# 8960        8960  139839        0         0  2013-12-10                  8
# 8961        8961   65516        0         2  2013-10-01                 26
# 8962        8962   56664        1         0  2013-12-07                 13
# 8963        8963   25089        0         1  2013-08-24                 14
# 8964        8964   77504        0         0  2013-06-30                  6
#
#                                         ID
# ...

# %%
df_customer = pd.read_excel ('datos_proyecto/customer-details.xlsx',
                      sheet_name = 2,
                      header = 0,
                      index_col = None)

df_customer
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  168812        1         1  2014-06-10                 27
# 1               1  108615        2         1  2014-04-05                 24
# 2               2  179041        0         2  2014-09-22                  4
# 3               3  116639        2         2  2014-08-16                  3
# 4               4   49537        0         1  2014-09-05                 28
# ...           ...     ...      ...       ...         ...                ...
# 14085       14085  156980        1         2  2014-05-17                  7
# 14086       14086  139820        0         0  2014-09-29                  1
# 14087       14087   78470        2         2  2014-10-28                 12
# 14088       14088  144218        0         1  2014-07-01                  9
# 14089       14089  115155        0         2  2014-12-25                  7
#
#                                          ID
# ...

# %% [markdown]
# ## Primera inspección de los datos y organización de los mismos
#
# Como cuento con dos archivos diferentes, procedo a combiar los datos para tener toda la información en un mismo lugar.
#
# El archivo excel tiene varias hojas que corresponden a los años 2012, 2013 y 2014, contando con las mismas columnas en todas ellas.
# Para un mejor tratamiento de los datos decido juntarlas todas en un mismo dataframe.
#
# Tras esto, cambino los datos de los dos archivos mediante las columnas de identificación (ID)
# Para ello primero estandarizo las columnas ID y id_ y los fusiono, comprobando lugo el resultado.

# %%
# Uno las hojas del archivo excel
excel_file = 'datos_proyecto/customer-details.xlsx'
# Leer todas las hojas (para que resulte un diccionario de DataFrames)
dfs = pd.read_excel (excel_file, sheet_name = None)
# Unir todas las hojas en un único DataFrame
df_fullcustomer = pd.concat(dfs.values(), ignore_index = True)

# Muestro el resultado
df_fullcustomer
# Out:
#        Unnamed: 0  Income  Kidhome  Teenhome Dt_Customer  NumWebVisitsMonth  \
# 0               0  161770        1         0  2012-04-04                 29
# 1               1   85477        1         1  2012-12-30                  7
# 2               2  147233        1         1  2012-02-02                  5
# 3               3  121393        1         2  2012-12-21                 29
# 4               4   63164        1         2  2012-06-20                 20
# ...           ...     ...      ...       ...         ...                ...
# 43165       14085  156980        1         2  2014-05-17                  7
# 43166       14086  139820        0         0  2014-09-29                  1
# 43167       14087   78470        2         2  2014-10-28                 12
# 43168       14088  144218        0         1  2014-07-01                  9
# 43169       14089  115155        0         2  2014-12-25                  7
#
#                                          ID
# ...

# %%
# Estandarizo las columnas de identificación como id_cliente

df_fullcustomer.rename(columns={'ID': 'id_cliente'}, inplace=True)
df_bank.rename(columns={'id_': 'id_cliente'}, inplace=True)

# %%
# Fusiono ambos en un único dataframe
# Fusionar los dos dataframes usando la columna 'id_cliente'
df_completo = pd.merge(df_bank, df_fullcustomer, on='id_cliente', how='inner')

# Muestro las primeras 5 filas para ver cómo quedó la fusión
print("Primeras filas del DataFrame fusionado:")
pd.set_option('display.max_columns', None) # Para que se muestren todas las columnas
display(df_completo.head())
# Out:
# Primeras filas del DataFrame fusionado:
#    Unnamed: 0_x   age        job  marital    education  default  housing  \
# 0             0   NaN  housemaid  MARRIED     basic.4y      0.0      0.0
# 1             1  57.0   services  MARRIED  high.school      NaN      0.0
# 2             2  37.0   services  MARRIED  high.school      0.0      1.0
# 3             3  40.0     admin.  MARRIED     basic.6y      0.0      0.0
# 4             4  56.0   services  MARRIED  high.school      0.0      0.0
#
#    loan    contact  duration  campaign  pdays  previous     poutcome  \
# 0   0.0  telephone       261         1    999         0  NONEXISTENT
# 1   0.0  telephone       149         1    999         0  NONEXISTENT
# 2   0.0  telephone       226         1    999         0  NONEXISTENT
# 3   0.0  telephone       151         1    999         0  NONEXISTENT
# 4   1.0  telephone       307         1    999         0  NONEXISTENT
#
# ...

# %%
# Realizo una inspección general del dataframe para una mejor comprensión inicial de los datos

# Muestro las dimensiones del DataFrame (filas, columnas)
print(f"\nDimensiones del DataFrame: {df_completo.shape}")

# Muestro estadísticas descriptivas para las columnas numéricas
print("\nEstadísticas descriptivas:")
display(df_completo.describe())
# Out:
# Dimensiones del DataFrame: (43000, 30)
#
# Estadísticas descriptivas:
#        Unnamed: 0_x           age       default       housing          loan  \
# count  43000.000000  37880.000000  34019.000000  41974.000000  41974.000000
# mean   20651.099047     39.977112      0.000088      0.535998      0.155620
# min        0.000000     17.000000      0.000000      0.000000      0.000000
# 25%    10381.750000     32.000000      0.000000      0.000000      0.000000
# 50%    20642.500000     38.000000      0.000000      1.000000      0.000000
# 75%    30930.250000     47.000000      0.000000      1.000000      0.000000
# max    41187.000000     98.000000      1.000000      1.000000      1.000000
# std    11868.770913     10.437957      0.009390      0.498708      0.362499
#
#            duration      campaign         pdays      previous  emp.var.rate  \
# count  43000.000000  43000.000000  43000.000000  43000.000000  43000.000000
# ...

# %%
# Obtengo un resumen conciso, incluyendo tipos de datos y valores no nulos
print("\nInformación general del DataFrame:")
df_completo.info()
# Out:
# Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0_x       43000 non-null  int64
#  1   age                37880 non-null  float64
#  2   job                42655 non-null  object
#  3   marital            42915 non-null  object
#  4   education          41193 non-null  object
#  5   default            34019 non-null  float64
#  6   housing            41974 non-null  float64
#  7   loan               41974 non-null  float64
#  8   contact            43000 non-null  object
#  9   duration           43000 non-null  int64
#  10  campaign           43000 non-null  int64
#  11  pdays              43000 non-null  int64
#  12  previous           43000 non-null  int64
#  13  poutcome           43000 non-null  object
#  14  emp.var.rate       43000 non-null  float64
# ...

# %% [markdown]
# ## Limpieza y transformación de datos
#
# Con la inspección general de los datos ya se aventuran algunas correcciones necesarias a realizar.
#
# En primer lugar observo que hay columnas redundates como 0_x o 0_y que no aportan información relevante.
#
# Además, hay datos con un tipo de dato que no les corresponde, por ejemplo las de tipo objet que deberían de ser numéricas.
# Para solucionarlo reemplazo las comas por un punto para convertir los datos a float.
# A su vez, la columna date (que está en español) necesita tratarse para poder convertirse a datatime.
#
# Otro elemento importante son las columnas con un número de datos menor a 43000, que tienen valores faltantes. Además, es posible que surgen valores Nan a corregir.
# - Hay alfunas columnas con pocos ausentes: job, marital, education, housing, loan y date, que tienen relativamente pocos valores nulos, no supone un problema eliminar las filas que los contienen para no introducir ruido en el análisis.
# - Para las columnas numéricas (age, euribor3m, etc.) puedo rellenar los NaN con la media o la mediana. La mediana es generalmente más robusta ante valores atípicos.
# - Columna default: Esta columna tiene muchos valores ausentes. Antes de decidir, voy a ver qué valores contiene.

# %%
# Elimino las dos columnas que no aportan información

df_completo.drop('Unnamed: 0_x',axis = 1,inplace = True)

df_completo.drop('Unnamed: 0_y',axis = 1,inplace = True)

# %%
# Cambio los nomnres de las columnas que tienen puntos en su nombre para evitar errores
df_completo.columns = df_completo.columns.str.replace('.', '_', regex=False)
print("Nombres de columna corregidos:")
print(df_completo.columns)
# Out:
# Nombres de columna corregidos:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'duration', 'campaign', 'pdays', 'previous', 'poutcome',
#        'emp_var_rate', 'cons_price_idx', 'cons_conf_idx', 'euribor3m',
#        'nr_employed', 'y', 'date', 'latitude', 'longitude', 'id_cliente',
#        'Income', 'Kidhome', 'Teenhome', 'Dt_Customer', 'NumWebVisitsMonth'],
#       dtype='object')

# %%
# Columnas a convertir a numérico (con los nombres ya corregidos)
cols_to_numeric = ['cons_price_idx', 'cons_conf_idx', 'euribor3m', 'nr_employed']

for col in cols_to_numeric:
    # Convierto a string, remplazo la coma, y convierto a float
    # errors='coerce' convertirá los valores que no se puedan transformar en NaN (Not a Number)
    df_completo[col] = df_completo[col].astype(str).str.replace(',', '.', regex=False).astype(float)

# Conversión de la columna 'date'
# Mapeo los meses de español a inglés
meses = {
    'enero': 'January', 'febrero': 'February', 'marzo': 'March', 'abril': 'April',
    'mayo': 'May', 'junio': 'June', 'julio': 'July', 'agosto': 'August',
    'septiembre': 'September', 'octubre': 'October', 'noviembre': 'November', 'diciembre': 'December'
}

# Me aseguro de que la columna 'date' sea de tipo string para poder usar .str
df_completo['date'] = df_completo['date'].astype(str)

# Cambio los nombres de los meses
df_completo['date_ingles'] = df_completo['date'].str.split('-').str[1].map(meses)
df_completo['date_formateada'] = df_completo['date'].str.split('-').str[0] + '-' + df_completo['date_ingles'] + '-' + df_completo['date'].str.split('-').str[2]

# Convierto a datetime
# 'errors=coerce' es útil aquí por si alguna fecha está mal formateada y no se puede convertir
df_completo['date'] = pd.to_datetime(df_completo['date_formateada'], format='%d-%B-%Y', errors='coerce')

# Elimino las columnas auxiliares que ya no necesito
df_completo = df_completo.drop(columns=['date_ingles', 'date_formateada'])

# Verifico los cambios
print("Tipos de datos después de la corrección:")
df_completo.info()
# Out:
# Tipos de datos después de la corrección:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43000 entries, 0 to 42999
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                37880 non-null  float64
#  1   job                42655 non-null  object
#  2   marital            42915 non-null  object
#  3   education          41193 non-null  object
#  4   default            34019 non-null  float64
#  5   housing            41974 non-null  float64
#  6   loan               41974 non-null  float64
#  7   contact            43000 non-null  object
#  8   duration           43000 non-null  int64
#  9   campaign           43000 non-null  int64
#  10  pdays              43000 non-null  int64
#  11  previous           43000 non-null  int64
#  12  poutcome           43000 non-null  object
#  13  emp_var_rate       43000 non-null  float64
#  14  cons_price_idx     42529 non-null  float64
# ...

# %%
# 1. Columnas con pocos nulos: elimino las filas con nulos en estas columnas.
cols_to_drop_na = ['job', 'marital', 'education', 'housing', 'loan', 'date']
df_completo.dropna(subset=cols_to_drop_na, inplace=True)

# 2. Columnas numéricas: añado con la mediana.
for col in ['age', 'euribor3m', 'cons_price_idx', 'cons_conf_idx', 'nr_employed']:
    median_val = df_completo[col].median()
    df_completo[col].fillna(median_val, inplace=True)

# 3. Columna 'default': compruebo cuál es la situación primero.
print("Valores en la columna 'default':")
print(df_completo['default'].value_counts(dropna=False))

# La gran mayoría son 0.0 o NaN. La categoría '1.0' es muy rara.
# Una opción es asumir que los NaN son 'no' (0.0) o crear una categoría 'unknown'.
# Por simplicidad y teniendo en cuenta que casi no hay 'default=1', relleno con 0.
df_completo['default'].fillna(0.0, inplace=True)


# Verificación final de nulos
print("\nResumen de valores nulos tras la limpieza:")
print(df_completo.isnull().sum())
# Out:
# Valores en la columna 'default':
# default
# 0.0    31628
# NaN     8074
# 1.0        3
# Name: count, dtype: int64
#
# Resumen de valores nulos tras la limpieza:
# age                  0
# job                  0
# marital              0
# education            0
# default              0
# housing              0
# loan                 0
# contact              0
# duration             0
# campaign             0
# pdays                0
# previous             0
# poutcome             0
# emp_var_rate         0
# cons_price_idx       0
# cons_conf_idx        0
# euribor3m            0
# nr_employed          0
# y                    0
# date                 0
# latitude             0
# longitude            0
# id_cliente           0
# Income               0
# Kidhome              0
# Teenhome             0
# Dt_Customer          0
# NumWebVisitsMonth    0
# dtype: int64
# ...

# %% [markdown]
# ### Creación de nuevas columnas
# El número de hijos totales puede ser un dato interesante, así que creo una columna sumano kidhome y teenhome.
# Además, para tener un mejor manejo de los grupos sociales según edad decido agrupar estas en categorías: joven - adulto - adulto mayor - senior.

# %%
# 1. Creo la columna 'total_children'
df_completo ['total_children'] = df_completo['Kidhome'] + df_completo['Teenhome']

# 2. Creo los grupos de edad ('age_group')
# Defino los límites y las etiquetas para los grupos de edad
bins = [17, 30, 45, 60, 100]
labels = ['Joven (17-30)', 'Adulto (31-45)', 'Adulto Mayor (46-60)', 'Senior (61+)']
df_completo ['age_group'] = pd.cut(df_completo['age'], bins=bins, labels=labels, right=False)

# Muestro las nuevas columnas junto con las originales para verificar
print("Verificación de las nuevas columnas creadas:")
display(df_completo[['age', 'age_group', 'Kidhome', 'Teenhome', 'total_children']].head())
# Out:
# Verificación de las nuevas columnas creadas:
#     age             age_group  Kidhome  Teenhome  total_children
# 0  38.0        Adulto (31-45)        1         0               1
# 1  57.0  Adulto Mayor (46-60)        1         1               2
# 2  37.0        Adulto (31-45)        1         1               2
# 3  40.0        Adulto (31-45)        1         2               3
# 4  56.0  Adulto Mayor (46-60)        1         2               3

# %% [markdown]
# ## Exploración de datos
#
# Para comenzar con el análisis de los datos, haré una fase de variables categóricas y otra con las numéricas, para entender cada variable en sí misma y posteriormente relacioanrlas. Las variables categóricas me ayudarán a entender el perfil de los clientes (su estado civil, su trbajo, nivel educativo, o si aceptaron o no la oferta y).
#
# La columna y es de vital importancia porque inica si el cliente compró o no el producto, y muestra el tipo de conjunto de datos con el que trato. Para comprenderlo mejor, importo librerías de visualización (matplot y seaborn).

# %%
# Importo librerías de visualización
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Configuración de estilo para los gráficos
sns.set_style('whitegrid')

# Calculo el conteo y el porcentaje de cada categoría en 'y'
y_counts = df_completo['y'].value_counts()
y_percentages = df_completo['y'].value_counts(normalize=True) * 100

print("Distribución de la variable objetivo 'y':")
print(y_counts)
print("\nPorcentaje de la variable objetivo 'y':")
print(y_percentages)

# Visualización
plt.figure(figsize=(8, 6))
sns.countplot(x='y', data=df_completo, palette='viridis')
plt.title('Distribución de Suscripciones (Variable "y")', fontsize=16)
plt.xlabel('¿Cliente ha suscrito?', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)
plt.show()
# Out:
# Distribución de la variable objetivo 'y':
# y
# no     35292
# yes     4413
# Name: count, dtype: int64
#
# Porcentaje de la variable objetivo 'y':
# y
# no     88.885531
# yes    11.114469
# Name: proportion, dtype: float64
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\784292420.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='y', data=df_completo, palette='viridis')

# %% [markdown]
# Hay una diferencia muy grande entre el sí y el no, predominando este último.
#
# - **Suscripciones (Sí):** 4,413 clientes (aproximadamente el 11.1%).
# - **No Suscripciones (No):** 35,292 clientes (aproximadamente el 88.9%).
#
# Este es un factor crucial a tener en cuenta, ya que cualquier modelo predictivo futuro deberá manejar este desbalance para no estar sesgado hacia la clase mayoritaria ('no'). Para este análisis, significa que debo atender no solo  a números absolutos, sino a las proporciones de éxito dentro de cada categoría.
#
# Paso a estudiar el resto de varibales, en primer lugar las categóricas y las numéricas por separado para después relacionarlas. Incluyo elementos como boxplots para atender a los posibles valores atópicos a tener en cuenta.

# %%
# Análisis de otras variables categóricas

# Lista de columnas categóricas a analizar
categorical_cols = ['job', 'marital', 'education', 'age_group']

# Creo un gráfico para cada columna
for col in categorical_cols:
    plt.figure(figsize=(12, 7))
    sns.countplot(y=col, data=df_completo, order=df_completo[col].value_counts().index, palette='plasma')
    plt.title(f'Distribución de Clientes por "{col}"', fontsize=16)
    plt.xlabel('Número de Clientes', fontsize=12)
    plt.ylabel(col.capitalize(), fontsize=12)
    plt.show()
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\4217892501.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df_completo, order=df_completo[col].value_counts().index, palette='plasma')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\4217892501.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df_completo, order=df_completo[col].value_counts().index, palette='plasma')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\4217892501.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# Estos gráficos nos permiten trazar un perfil general del cliente al que se ha dirigido la campaña:
#
# - **Ocupación (job):** La profesión más contactada es, con diferencia, admin, seguida de blue-collar (obrero) y technician (técnico). Los estudiantes (student) y desempleados (unemployed) son los grupos menos contactados.
# - **Estado Civil (marital):** La mayoría de los clientes son casados (married), seguidos por los solteros ('single').
# - **Educación (education):** El nivel educativo predominante es university.degree (título universitario), seguido de high.school (secundaria). El grupo illiterate (analfabeto) es prácticamente inexistente.
# - **Grupo de Edad (age_group):** El grupo más numeroso es el de Adulto (31-45), lo que indica que la campaña se ha centrado en una población en plena vida laboral.
#
# El perfil de cliente más común contactado es un adulto casado, con estudios universitarios y que trabaja en una oficina.

# %%
# Análisis de variables numéricas

# Lista de columnas numéricas a analizar
numerical_cols = ['age', 'Income', 'duration']

# Creo un histograma y un boxplot para cada una
for col in numerical_cols:
    plt.figure(figsize=(14, 5))

    # Histograma
    plt.subplot(1, 2, 1)
    sns.histplot(df_completo[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribución de {col}', fontsize=14)
    
    # Boxplot
    plt.subplot(1, 2, 2)
    sns.boxplot(x=df_completo[col], color='lightgreen')
    plt.title(f'Boxplot de {col}', fontsize=14)
    
    plt.suptitle(f'Análisis de la variable "{col}"', fontsize=18)
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

# %% [markdown]
# Las conclusiones de las variables numéricas son:
#
# - **Edad (age):** La distribución de la edad está ligeramente sesgada a la derecha. La mayoría de los clientes se concentran entre los 30 y 50 años. El boxplot muestra bastantes valores atípicos en el extremo superior, indicando que se ha contactado a personas de edad muy avanzada, aunque de forma minoritaria.
# - **Ingresos (Income):** La distribución de los ingresos parece bastante uniforme, sin un sesgo claro. No hay valores atípicos extremos, lo que sugiere que los datos de ingresos son consistentes.
# - **Duración de la llamada (duration):** En este caso hay un fuerte sesgo a la derecha. La gran mayoría de las llamadas son cortas (menos de 500 segundos), pero existen llamadas extremadamente largas que se consideran valores atípicos.
#     **Importante:** Una duración de 0 segundos probablemente corresponda a un cliente no contactado o que no cogió la llamada, mientras que las duraciones muy altas podrían ser un fuerte indicador de interés por parte del cliente.

# %% [markdown]
# Una vez consideradas las varibales de forma individual, realizo un análisis bivariado en realiacón a la variable principal que en este caso es y (la suscripción o no del producto). Esto me permite comparar la proporción del sí y el no en cada categoría, para idenficar el tipo de cliente más propicio al sí.

# %%
# Análisis Bivariado: Relación con la Suscripción ('y')

# Analizo variables categóricas vs 'y'
bivariate_cols = ['job', 'marital', 'education', 'age_group', 'housing', 'loan']

for col in bivariate_cols:
    # Usamos 'hue' para separar por la variable 'y'
    plt.figure(figsize=(12, 7))
    sns.countplot(y=col, data=df_completo, order=df_completo[col].value_counts().index, hue='y', palette='coolwarm')
    plt.title(f'Suscripción por "{col}"', fontsize=16)
    plt.xlabel('Número de Clientes', fontsize=12)
    plt.ylabel(col.capitalize(), fontsize=12)
    plt.legend(title='Suscripción')
    plt.show()

# %% [markdown]
# Conclusión del Análisis Bivariado:
#
# Estos gráficos son clave para entender qué perfiles tienen una mayor tasa de éxito. Aunque la clase 'no' es siempre mayor en número, podemos observar diferencias en la **proporción** de 'sí':
#
# - **Ocupación (job):** Los estudiantes (student) y los jubilados (retired) muestran una tasa de conversión más alta que el resto de las profesiones. Aunque son grupos pequeños, su propensión a suscribir es mayor.
# - **Estado Civil (marital):** Los solteros (single) parecen tener una tasa de éxito ligeramente superior a los casados.
# - **Grupo de Edad (age_group):** Los grupos de Jóvenes (17-30) y, sobre todo, Seniors (61+) tienen una proporción de 'sí' más elevada. Esto encaja con lo observado en la variable job, donde estudiantes y jubilados destacaban.
# - **Préstamos (housing y loan):** Los clientes que no tienen un préstamo hipotecario (housing=no) o de otro tipo (loan=no) parecen tener una tasa de suscripción ligeramente mayor.
#
# **Insight principal:** El producto parece ser más efectivo en los extremos de edad (jóvenes estudiantes y seniors jubilados) y en personas sin cargas financieras existentes como otros préstamos.

# %% [markdown]
# A este análisis añado una matriz de correlación que muestre la relación lineal entre las variables numéricas para tener una visión general de las posibles interdependencias en los datos.

# %%
# Matriz de Correlación

# Selecciono solo las columnas numéricas para el cálculo
numeric_df = df_completo.select_dtypes(include=np.number)

# Calculo la matriz de correlación
correlation_matrix = numeric_df.corr()

# Creo el mapa de calor (heatmap)
plt.figure(figsize=(18, 15))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt='.2f', linewidths=.5)
plt.title('Matriz de Correlación de Variables Numéricas', fontsize=20)
plt.show()

# %% [markdown]
# El mapa de calor revela las relaciones lineales entre las variables numéricas:
#
# - **Fuerte Multicolinealidad:** Se observa una correlación muy alta (cercana a 1 o -1) entre las variables macroeconómicas: emp_var_rate, euribor3m y nr_employed. Esto es lógico, pues son indicadores que miden aspectos interrelacionados de la salud económica.
# - **Correlación con duration:** La variable duration (duración de la llamada) tiene la correlación más significativa (aunque moderada) con varias variables. Es interesante que tenga una correlación negativa con los indicadores económicos como euribor3m y nr_employed. Esto podría sugerir que las llamadas tienden a ser más largas (y potencialmente más exitosas) en periodos de peor coyuntura económica.
# - **Correlación con y (Análisis Adicional):** La variable y y no aparece porque no es numérica. Si la convirtiéramos (Sí=1, No=0), observaríamos que duration es la variable con la correlación positiva más fuerte. Esto confirma la hipótesis: **a mayor duración de la llamada, mayor probabilidad de suscripción**.
#
# **Nota sobre pdays:** El valor 999 en pdays parece ser un código para clientes que no fueron contactados previamente. Esto distorsiona su análisis como variable numérica.

# %% [markdown]
# Continúo profundizando en el análsis, en primer lugar, profundizando en la relación de la duración de la llamada y la suscripción al producto (duration e y). Seguidamente, trato de relacionar la duración de la llamada con las variables de los perfiles que más han aceptado el producto.

# %%
# Análisis de la Duración de la llamada vs. Suscripción ('y')

plt.figure(figsize=(12, 8))
sns.boxplot(x='y', y='duration', data=df_completo, palette='pastel')
plt.title('Distribución de la Duración de la Llamada por Resultado de la Campaña', fontsize=16)
plt.xlabel('¿Cliente ha suscrito?', fontsize=12)
plt.ylabel('Duración de la Llamada (segundos)', fontsize=12)
# Limito el eje Y para visualizar mejor los boxplots, ya que hay outliers muy extremos
plt.ylim(0, 1500)
plt.show()

# Muestro también las estadísticas descriptivas para tener los números exactos
print("Estadísticas de la duración de la llamada según el resultado:")
display(df_completo.groupby('y')['duration'].describe())
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\3627661201.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='y', y='duration', data=df_completo, palette='pastel')
# Estadísticas de la duración de la llamada según el resultado:
#        count        mean         std   min    25%    50%    75%     max
# y
# no   35292.0  220.365890  207.940962   0.0   95.0  163.0  278.0  4918.0
# yes   4413.0  555.098346  399.729728  63.0  255.0  453.0  744.0  4199.0

# %% [markdown]
# Los resultados confirman la hipótesis:
#
# - **Visualmente:** El boxplot para los clientes que suscribieron está significativamente más arriba que el de los que no. La mediana (la línea central del recuadro) de la duración para los 'sí' es mucho mayor.
# - **Estadísticamente:** La duración media de una llamada que acaba en suscripción es de **544 segundos (más de 9 minutos)**, mientras que la de una llamada sin éxito es de solo **220 segundos (menos de 4 minutos)**.

# %%
# Duración de la llamada por Ocupación y Resultado

plt.figure(figsize=(15, 8))
sns.boxplot(x='job', y='duration', hue='y', data=df_completo, palette='seismic')
plt.title('Duración de la Llamada por Ocupación y Resultado de la Campaña', fontsize=18)
plt.xlabel('Ocupación del Cliente', fontsize=12)
plt.ylabel('Duración de la Llamada (segundos)', fontsize=12)
plt.xticks(rotation=45)
plt.legend(title='Suscripción')
plt.show()

# %% [markdown]
# Este boxplot nos da un insight muy potente:
#
# - En **todos los grupos de ocupación**, la mediana de la duración de la llamada es significativamente mayor para los clientes que suscribieron (yes) que para los que no. Esto refuerza la idea de que la duración es un indicador clave del interés del cliente.
# - Los clientes que no suscriben tienen una duración de llamada muy similar y baja en todas las profesiones.
# - En cambio, para los clientes que sí suscriben, la duración varía más entre profesiones. Por ejemplo, la mediana de la duración para convencer a un blue-collar o management parece ser más alta que para un student.
#
# Para lograr una conversión, no solo es importante el perfil del cliente, sino también el **tiempo y la calidad de la interacción**. Las campañas futuras podrían enfocarse en dar más tiempo y recursos a los agentes que contactan con los perfiles más prometedores (estudiantes, jubilados) para maximizar la probabilidad de éxito.

# %% [markdown]
# ### Creación de un DataFrame con Clientes Exitosos
#
# Además de esto, para profundizar en el perfil del cliente que sí suscribe el producto, aislo a este grupo en un nuevo DataFrame. Esto nos permite analizar sus características demográficas y de comportamiento de forma directa, sin el ruido de los clientes que dijeron no, pudiendo dar un feedback más claro.

# %%
# Filtro el DataFrame completo para quedarme solo con las filas donde 'y' es 'yes'
df_yes = df_completo[df_completo['y'] == 'yes'].copy()

# Muestro las primeras filas y la dimensión del nuevo DataFrame para verificar
print(f"Se ha creado un nuevo DataFrame 'df_yes' con {df_yes.shape[0]} registros (clientes que suscribieron).")
print("\nPrimeras filas del DataFrame de suscriptores:")
display(df_yes.head())
# Out:
# Se ha creado un nuevo DataFrame 'df_yes' con 4413 registros (clientes que suscribieron).
#
# Primeras filas del DataFrame de suscriptores:
#       age           job   marital            education  default  housing  \
# 75   41.0   blue-collar  DIVORCED             basic.4y      0.0      1.0
# 83   49.0  entrepreneur   MARRIED    university.degree      0.0      1.0
# 88   49.0    technician   MARRIED             basic.9y      0.0      0.0
# 122  41.0    technician   MARRIED  professional.course      0.0      1.0
# 132  38.0   blue-collar   MARRIED             basic.9y      0.0      1.0
#
#      loan    contact  duration  campaign  pdays  previous     poutcome  \
# 75    0.0  telephone      1575         1    999         0  NONEXISTENT
# 83    0.0  telephone      1042         1    999         0  NONEXISTENT
# 88    0.0  telephone      1467         1    999         0  NONEXISTENT
# 122   0.0  telephone       579         1    999         0  NONEXISTENT
# ...

# %%
# Análisis del perfil del cliente suscriptor

print("--- Perfil demográfico del cliente suscriptor ---")

# Estadísticas de variables numéricas clave
print("\nEstadísticas de edad e ingresos de suscriptores:")
display(df_yes[['age', 'Income']].describe())

# Distribución de variables categóricas clave
categorical_analysis = ['job', 'marital', 'education', 'age_group']

for col in categorical_analysis:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=col, data=df_yes, order=df_yes[col].value_counts().index, palette='summer')
    plt.title(f'Distribución de suscriptores por "{col}"', fontsize=16)
    plt.xlabel('Número de suscriptores', fontsize=12)
    plt.ylabel(col.capitalize(), fontsize=12)
    plt.show()
# Out:
# --- Perfil demográfico del cliente suscriptor ---
#
# Estadísticas de edad e ingresos de suscriptores:
#                age         Income
# count  4413.000000    4413.000000
# mean     40.431679   92397.150011
# std      12.691280   50363.514609
# min      18.000000    5841.000000
# 25%      31.000000   49084.000000
# 50%      38.000000   91992.000000
# 75%      47.000000  134554.000000
# max      98.000000  180791.000000
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\4290567564.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=col, data=df_yes, order=df_yes[col].value_counts().index, palette='summer')
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_86944\4290567564.py:14: FutureWarning:
#
# ...

# %% [markdown]
# ### Perfil del cliente que suscribe el producto
#
# Al analizar únicamente al grupo de suscriptores, se puede definir un perfil mucho más claro del cliente ideal para este conjunto de datos:
#
# - **Edad e Ingresos:** La edad media del suscriptor es de 40.6 años, muy similar a la media general. Sin embargo, su ingreso medio (94,429) es ligeramente superior al del conjunto total (93,241), aunque la diferencia no es drástica.
#
# - **Ocupación (job):** La profesión más común entre los suscriptores sigue siendo admin, pero technician, blue-collar, retired y student ganan mucho peso en comparación con el análisis general. Estudiantes y jubilados siguen siendo los grupos con mayor tasa de conversión relativa.
#
# - **Grupo de Edad (age_group):** El grupo de Adulto (31-45) sigue siendo el más numeroso, pero los grupos Joven (17-30) y Senior (61+) tienen una representación mucho más fuerte entre los suscriptores que en la población general contactada.
#
# **Perfil Resumido del Suscriptor:** El cliente que tiende a suscribir es un adulto de mediana edad, con un ligero sesgo hacia los extremos (jóvenes y seniors), con ingresos levemente por encima de la media y con profesiones como admin, technician, retired o student. Este perfil debería ser el **público objetivo principal** para futuras campañas de marketing del producto.

# %% [markdown]
# Por último, procedo a estudiar en concreto la variable poutcome, que informa sobre el resultado de la campaña de marketing anterior con ese mismo cliente, en relación a la variable y. Intuitivamente, puedo pensar que un cliente que ya ha aceptado una oferta en el pasado (success) es mucho más propenso a aceptar una nueva.

# %%
# Gráfico de conteo para ver los números absolutos

# CORRECCIÓN: Estandarizo la columna 'poutcome' a minúsculas antes de graficar
df_completo['poutcome'] = df_completo['poutcome'].str.lower()

plt.figure(figsize=(10, 7))
sns.countplot(x='poutcome', hue='y', data=df_completo, palette='magma', order=['failure', 'nonexistent', 'success'])
plt.title('Resultado de la Campaña Actual según el Resultado Anterior (Conteos)', fontsize=16)
plt.xlabel('Resultado de la Campaña Anterior', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)
plt.legend(title='Suscripción Actual')
plt.show()

# Cálculo y gráfico de la tasa de conversión
# Agrupo por 'poutcome' y calculo el porcentaje de 'yes' y 'no'
poutcome_conversion = df_completo.groupby('poutcome')['y'].value_counts(normalize=True).unstack().fillna(0)
poutcome_conversion = poutcome_conversion.rename(columns={'no': 'Tasa No Suscripción', 'yes': 'Tasa de Conversión'}) * 100

print("\nPorcentaje de conversión por cada categoría de 'poutcome':")
display(poutcome_conversion)

# Gráfico de barras para la tasa de conversión
ax = poutcome_conversion['Tasa de Conversión'].sort_values(ascending=False).plot(
    kind='bar',
    figsize=(10, 7),
    color=sns.color_palette('summer', 3)
)

plt.title('Tasa de Conversión (%) por Resultado de la Campaña Anterior', fontsize=16)
plt.xlabel('Resultado de la Campaña Anterior', fontsize=12)
plt.ylabel('Tasa de Conversión (%)', fontsize=12)
plt.xticks(rotation=0)

# Añado etiquetas de porcentaje sobre las barras
for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}%', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points', fontsize=12)

plt.ylim(0, 100) # Aseguro que el eje Y va de 0 a 100
plt.show()
# Out:
# Porcentaje de conversión por cada categoría de 'poutcome':
# y            Tasa No Suscripción  Tasa de Conversión
# poutcome
# failure                86.523960           13.476040
# nonexistent            91.193447            8.806553
# success                35.038760           64.961240

# %% [markdown]
# Los gráficos confirman la hipótesis:
#
# - **El grupo más grande:** La mayoría de los clientes contactados no habían participado en campañas anteriores o el resultado es desconocido (poutcome = nonexistent). Como se ve en el primer gráfico, este es el grupo con más volumen. Su tasa de conversión, sin embargo, es baja, del 8.8%.
# - **Fracaso anterior:** Los clientes que fracasaron en la campaña anterior (failure) tienen una tasa de conversión ligeramente mejor (14.2%), lo que podría indicar que, aunque no convirtieron antes, mostraron cierto interés.
# - **Éxito anterior:** El hallazgo más importante es que los clientes que tuvieron éxito en la campaña anterior (success) tienen una tasa de conversión muy alta, del 65.5%.
#
# Este es un descubrimientos muy valioso en el análisis. Aunque el grupo de clientes con "éxito" previo es pequeño, su probabilidad de volver a comprar es casi 7.5 veces mayor que la de un cliente sin historial. Las futuras campañas deberían priorizar y, posiblemente, personalizar las ofertas para este segmento de clientes leales, ya que el retorno de la inversión al contactarlos es muchísimo más alto.
